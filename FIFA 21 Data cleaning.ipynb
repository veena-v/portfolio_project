# %%
import pandas as pd
import numpy as np
df = pd.read_csv('players_21.csv')

# %%
df.head()
# Out:
#    sofifa_id         short_name                            long_name  \
# 0     158023           L. Messi       Lionel Andrés Messi Cuccittini
# 1      20801  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro
# 2     188545     R. Lewandowski                   Robert Lewandowski
# 3     190871          Neymar Jr        Neymar da Silva Santos Júnior
# 4     192985       K. De Bruyne                      Kevin De Bruyne
#
#   player_positions  overall  potential    value_eur  wage_eur  age  \
# 0       RW, ST, CF       93         93  103500000.0  560000.0   33
# 1           ST, LW       92         92   63000000.0  220000.0   35
# 2               ST       91         91  111000000.0  240000.0   31
# 3          LW, CAM       91         91  132000000.0  270000.0   28
# 4          CAM, CM       91         91  129000000.0  370000.0   29
#
#           dob  height_cm  weight_kg  club_team_id            club_name  \
# 0  24/06/1987        170         72         241.0         FC Barcelona
# ...

# %%
# checking for missing values

for cols in df.columns:
    missing = np.mean(df[cols].isnull())
    print(cols, missing, missing>0)
# Out:
# sofifa_id 0.0 False
# short_name 0.0 False
# long_name 0.0 False
# player_positions 0.0 False
# overall 0.0 False
# potential 0.0 False
# value_eur 0.012510557432432432 True
# wage_eur 0.011877111486486486 True
# age 0.0 False
# dob 0.0 False
# height_cm 0.0 False
# weight_kg 0.0 False
# club_team_id 0.011877111486486486 True
# club_name 0.011877111486486486 True
# league_name 0.011877111486486486 True
# league_level 0.011877111486486486 True
# club_position 0.011877111486486486 True
# club_jersey_number 0.011877111486486486 True
# club_joined 0.05188978040540541 True
# club_contract_valid_until 0.011877111486486486 True
# nationality_id 0.0 False
# nationality_name 0.0 False
# player_traits 0.5610747466216216 True

# %%
df.dropna(inplace= True)

# %%
for cols in df.columns:
    missing = np.mean(df[cols].isnull())
    print(cols, missing, missing>0)
# Out:
# sofifa_id 0.0 False
# short_name 0.0 False
# long_name 0.0 False
# player_positions 0.0 False
# overall 0.0 False
# potential 0.0 False
# value_eur 0.0 False
# wage_eur 0.0 False
# age 0.0 False
# dob 0.0 False
# height_cm 0.0 False
# weight_kg 0.0 False
# club_team_id 0.0 False
# club_name 0.0 False
# league_name 0.0 False
# league_level 0.0 False
# club_position 0.0 False
# club_jersey_number 0.0 False
# club_joined 0.0 False
# club_contract_valid_until 0.0 False
# nationality_id 0.0 False
# nationality_name 0.0 False
# player_traits 0.0 False

# %%
df.dtypes
# Out:
# sofifa_id                      int64
# short_name                    object
# long_name                     object
# player_positions              object
# overall                        int64
# potential                      int64
# value_eur                    float64
# wage_eur                     float64
# age                            int64
# dob                           object
# height_cm                      int64
# weight_kg                      int64
# club_team_id                 float64
# club_name                     object
# league_name                   object
# league_level                 float64
# club_position                 object
# club_jersey_number           float64
# club_joined                   object
# club_contract_valid_until    float64
# nationality_id                 int64
# nationality_name              object
# player_traits                 object
# dtype: object

# %%
df.head()
# Out:
#    sofifa_id         short_name                            long_name  \
# 0     158023           L. Messi       Lionel Andrés Messi Cuccittini
# 1      20801  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro
# 2     188545     R. Lewandowski                   Robert Lewandowski
# 3     190871          Neymar Jr        Neymar da Silva Santos Júnior
# 4     192985       K. De Bruyne                      Kevin De Bruyne
#
#   player_positions  overall  potential    value_eur  wage_eur  age  \
# 0       RW, ST, CF       93         93  103500000.0  560000.0   33
# 1           ST, LW       92         92   63000000.0  220000.0   35
# 2               ST       91         91  111000000.0  240000.0   31
# 3          LW, CAM       91         91  132000000.0  270000.0   28
# 4          CAM, CM       91         91  129000000.0  370000.0   29
#
#           dob  height_cm  weight_kg  club_team_id            club_name  \
# 0  24/06/1987        170         72         241.0         FC Barcelona
# ...

# %%
df['year'] = df['club_joined'].astype('str').str[:4]

# %%
df.head(5)
# Out:
#    sofifa_id         short_name                            long_name  \
# 0     158023           L. Messi       Lionel Andrés Messi Cuccittini
# 1      20801  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro
# 2     188545     R. Lewandowski                   Robert Lewandowski
# 3     190871          Neymar Jr        Neymar da Silva Santos Júnior
# 4     192985       K. De Bruyne                      Kevin De Bruyne
#
#   player_positions  overall  potential    value_eur  wage_eur  age  \
# 0       RW, ST, CF       93         93  103500000.0  560000.0   33
# 1           ST, LW       92         92   63000000.0  220000.0   35
# 2               ST       91         91  111000000.0  240000.0   31
# 3          LW, CAM       91         91  132000000.0  270000.0   28
# 4          CAM, CM       91         91  129000000.0  370000.0   29
#
#           dob  height_cm  weight_kg  club_team_id            club_name  \
# 0  24/06/1987        170         72         241.0         FC Barcelona
# ...

# %%
df_copy = df.copy()

# %%
df_copy['month'] = df_copy['club_joined'].astype('str').str[5:7]

# %%
df_copy.head(5)
# Out:
#    sofifa_id         short_name                            long_name  \
# 0     158023           L. Messi       Lionel Andrés Messi Cuccittini
# 1      20801  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro
# 2     188545     R. Lewandowski                   Robert Lewandowski
# 3     190871          Neymar Jr        Neymar da Silva Santos Júnior
# 4     192985       K. De Bruyne                      Kevin De Bruyne
#
#   player_positions  overall  potential    value_eur  wage_eur  age  \
# 0       RW, ST, CF       93         93  103500000.0  560000.0   33
# 1           ST, LW       92         92   63000000.0  220000.0   35
# 2               ST       91         91  111000000.0  240000.0   31
# 3          LW, CAM       91         91  132000000.0  270000.0   28
# 4          CAM, CM       91         91  129000000.0  370000.0   29
#
#           dob  height_cm  weight_kg  club_team_id            club_name  \
# 0  24/06/1987        170         72         241.0         FC Barcelona
# ...

# %%
df_copy['day'] = df_copy['club_joined'].astype('str').str[8:10]

# %%
df_copy['club_contract_valid_until'] = df_copy['club_contract_valid_until'].astype('int64')

# %%
df.head()
# Out:
#    sofifa_id         short_name                            long_name  \
# 0     158023           L. Messi       Lionel Andrés Messi Cuccittini
# 1      20801  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro
# 2     188545     R. Lewandowski                   Robert Lewandowski
# 3     190871          Neymar Jr        Neymar da Silva Santos Júnior
# 4     192985       K. De Bruyne                      Kevin De Bruyne
#
#   player_positions  overall  potential    value_eur  wage_eur  age  \
# 0       RW, ST, CF       93         93  103500000.0  560000.0   33
# 1           ST, LW       92         92   63000000.0  220000.0   35
# 2               ST       91         91  111000000.0  240000.0   31
# 3          LW, CAM       91         91  132000000.0  270000.0   28
# 4          CAM, CM       91         91  129000000.0  370000.0   29
#
#           dob  height_cm  weight_kg  club_team_id            club_name  \
# 0  24/06/1987        170         72         241.0         FC Barcelona
# ...

# %%
df_copy['value_eur'] = df_copy['value_eur'].astype('int64')

# %%
df_copy['wage_eur'] = df_copy['wage_eur'].astype('int64')

# %%
df_copy['club_team_id'] = df_copy['club_team_id'].astype('int64')

# %%
df_copy['league_level'] = df_copy['league_level'].astype('int64')

# %%
df_copy['club_jersey_number'] = df_copy['club_jersey_number'].astype('int64')

# %%
df_copy.dtypes
# Out:
# sofifa_id                     int64
# short_name                   object
# long_name                    object
# player_positions             object
# overall                       int64
# potential                     int64
# value_eur                     int64
# wage_eur                      int64
# age                           int64
# dob                          object
# height_cm                     int64
# weight_kg                     int64
# club_team_id                  int64
# club_name                    object
# league_name                  object
# league_level                  int64
# club_position                object
# club_jersey_number            int64
# club_joined                  object
# club_contract_valid_until     int64
# nationality_id                int64
# nationality_name             object
# player_traits                object
# year                         object
# month                        object
# day                          object
# ...

# %%
df_copy.head()
# Out:
#    sofifa_id         short_name                            long_name  \
# 0     158023           L. Messi       Lionel Andrés Messi Cuccittini
# 1      20801  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro
# 2     188545     R. Lewandowski                   Robert Lewandowski
# 3     190871          Neymar Jr        Neymar da Silva Santos Júnior
# 4     192985       K. De Bruyne                      Kevin De Bruyne
#
#   player_positions  overall  potential  value_eur  wage_eur  age         dob  \
# 0       RW, ST, CF       93         93  103500000    560000   33  24/06/1987
# 1           ST, LW       92         92   63000000    220000   35  05/02/1985
# 2               ST       91         91  111000000    240000   31  21/08/1988
# 3          LW, CAM       91         91  132000000    270000   28  05/02/1992
# 4          CAM, CM       91         91  129000000    370000   29  28/06/1991
#
#    height_cm  weight_kg  club_team_id            club_name  \
# ...
